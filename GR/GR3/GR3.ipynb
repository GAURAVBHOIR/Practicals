# %%
pip install git+https://github.com/einsteinpy/einsteinpy.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/einsteinpy/einsteinpy.git
#   Cloning https://github.com/einsteinpy/einsteinpy.git to /tmp/pip-req-build-kc6yvmcv
#   Running command git clone --filter=blob:none --quiet https://github.com/einsteinpy/einsteinpy.git /tmp/pip-req-build-kc6yvmcv
#   Resolved https://github.com/einsteinpy/einsteinpy.git to commit e7d708645f5b44168d8981b8cd5f1784a459378c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.4 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (1.26.4)
# Requirement already satisfied: astropy>=5.1.1 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (6.1.2)
# Requirement already satisfied: matplotlib>=3.6.2 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (3.9.0)
# Requirement already satisfied: scipy>=1.9.3 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (1.13.1)
# Requirement already satisfied: plotly>=5.11.0 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (5.22.0)
# Requirement already satisfied: sympy>=1.11.1 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (1.12.1)
# Requirement already satisfied: numba!=0.49.0,>=0.56.3 in ./.local/lib/python3.12/site-packages (from einsteinpy==0.5.dev0) (0.60.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in ./.local/lib/python3.12/site-packages (from astropy>=5.1.1->einsteinpy==0.5.dev0) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.1.0.34.3 in ./.local/lib/python3.12/site-packages (from astropy>=5.1.1->einsteinpy==0.5.dev0) (0.2024.7.22.0.34.13)
# Requirement already satisfied: PyYAML>=3.13 in /usr/lib64/python3.12/site-packages (from astropy>=5.1.1->einsteinpy==0.5.dev0) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/lib/python3.12/site-packages (from astropy>=5.1.1->einsteinpy==0.5.dev0) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (1.4.5)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.12/site-packages (from matplotlib>=3.6.2->einsteinpy==0.5.dev0) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.local/lib/python3.12/site-packages (from numba!=0.49.0,>=0.56.3->einsteinpy==0.5.dev0) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./.local/lib/python3.12/site-packages (from plotly>=5.11.0->einsteinpy==0.5.dev0) (8.4.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in ./.local/lib/python3.12/site-packages (from sympy>=1.11.1->einsteinpy==0.5.dev0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->einsteinpy==0.5.dev0) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import astropy.units as u
import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt

from einsteinpy.geodesic import Nulllike
from einsteinpy.plotting import StaticGeodesicPlotter

from einsteinpy.coordinates import BoyerLindquistDifferential
from einsteinpy.metric import Kerr

# %%
# Metric or Black Hole parameters - Mass, M and Spin Parameter, a
M = 5e30 * u.kg
a1 = 0.15 * u.one
a2 = 0.999999999 * u.one # Extremal Kerr Black Hole

# Coordinate object to initialize metric with
# Note that, for this example
# the coordinate values below are irrelevant
bl = BoyerLindquistDifferential(
    t=0. * u.s,
    r=1e3 * u.m,
    theta=np.pi / 2 * u.rad,
    phi=np.pi * u.rad,
    v_r=0. * u.m / u.s,
    v_th=0. * u.rad / u.s,
    v_p=0. * u.rad / u.s,
)

# Defining two Kerr Black Holes, one with a higher spin parameter
kerr1 = Kerr(coords=bl, M=M, a=a1)
kerr2 = Kerr(coords=bl, M=M, a=a2)

# Getting the list of singularities
sing_dict1 = kerr1.singularities()
sing_dict2 = kerr2.singularities()

# Let's check the contents of the dicts
# 'ergosphere' entries should be functions
print(sing_dict1, sing_dict2, sep="\n\n")
# Out:
# {'inner_ergosphere': <function BaseMetric.singularities.<locals>._in_ergo at 0x7f378adf9b20>, 'inner_horizon': 42.00980102827634, 'outer_horizon': 7384.150468090389, 'outer_ergosphere': <function BaseMetric.singularities.<locals>._out_ergo at 0x7f378ad73560>}
#
# {'inner_ergosphere': <function BaseMetric.singularities.<locals>._in_ergo at 0x7f378ad73100>, 'inner_horizon': 3712.914080573008, 'outer_horizon': 3713.2461885456573, 'outer_ergosphere': <function BaseMetric.singularities.<locals>._out_ergo at 0x7f378ad736a0>}

# %%
# Sampling Polar Angle for plotting in Polar Coordinates
theta = np.linspace(0, 2 * np.pi, 100)

# Ergospheres
# These are functions
Ei1, Eo1 = sing_dict1["inner_ergosphere"], sing_dict1["outer_ergosphere"]
Ei2, Eo2 = sing_dict2["inner_ergosphere"], sing_dict2["outer_ergosphere"]

# Creating lists of points on Ergospheres for different polar angles, for both black holes
Ei1_list, Eo1_list = Ei1(theta), Eo1(theta)
Ei2_list, Eo2_list = Ei2(theta), Eo2(theta)

# For Black Hole 1 (a = 0.4)
Xei1 = Ei1_list * np.sin(theta)
Yei1 = Ei1_list * np.cos(theta)

Xeo1 = Eo1_list * np.sin(theta)
Yeo1 = Eo1_list * np.cos(theta)

# For Black Hole 2 (a = 0.9)
Xei2 = Ei2_list * np.sin(theta)
Yei2 = Ei2_list * np.cos(theta)

Xeo2 = Eo2_list * np.sin(theta)
Yeo2 = Eo2_list * np.cos(theta)

# Event Horizons
Hi1, Ho1 = sing_dict1["inner_horizon"], sing_dict1["outer_horizon"]
Hi2, Ho2 = sing_dict2["inner_horizon"], sing_dict2["outer_horizon"]

# For Black Hole 1 (a = 0.4)
Xhi1 = Hi1 * np.sin(theta)
Yhi1 = Hi1 * np.cos(theta)

Xho1 = Ho1 * np.sin(theta)
Yho1 = Ho1 * np.cos(theta)

# For Black Hole 2 (a = 0.9)
Xhi2 = Hi2 * np.sin(theta)
Yhi2 = Hi2 * np.cos(theta)

Xho2 = Ho2 * np.sin(theta)
Yho2 = Ho2 * np.cos(theta)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,7.5))

ax1.fill(Xei1, Yei1, 'b', Xeo1, Yeo1, 'r', Xhi1, Yhi1, 'b', Xho1, Yho1, 'r', alpha=0.3)
ax1.set_title(f"$M = {M}, a = {a1}$", fontsize=18)
ax1.set_xlabel("X", fontsize=18)
ax1.set_ylabel("Y", fontsize=18)
ax1.set_xlim([-6100, 6100])
ax1.set_ylim([-6100, 6100])

ax2.fill(Xei2, Yei2, 'b', Xeo2, Yeo2, 'r', Xhi2, Yhi2, 'b', Xho2, Yho2, 'r', alpha=0.3)
ax2.set_title(f"$M = {M}, a = {a2}$", fontsize=18)
ax2.set_xlabel("X", fontsize=18)
ax2.set_ylabel("Y", fontsize=18)
ax2.set_xlim([-6100, 6100])
ax2.set_ylim([-6100, 6100])
# Out:
# (-6100.0, 6100.0)

# %%
position = [2.5, np.pi / 2, 0.]
momentum = [0., 0., -2.]
a = 0.2
steps = 7440  # As close as we can get before the integration becomes highly unstable
delta = 0.0005
omega = 0.01
suppress_warnings = True

# %%
geod = Nulllike(
    metric="Kerr",
    metric_params=(a,),
    position=position,
    momentum=momentum,
    steps=steps,
    delta=delta,
    return_cartesian=True,
    omega=omega,
    suppress_warnings=suppress_warnings
)

# %%
sgpl = StaticGeodesicPlotter(bh_colors=('red','black'))
sgpl.plot(geod,color='blue',title='3-D plot',aspect='equal' )
sgpl.show()

# %%
sgpl = StaticGeodesicPlotter(bh_colors=("red", "blue"))
sgpl.plot2D(geod, coordinates=(1, 2), figsize=(10, 10), color="indigo") # Plot X vs Y
sgpl.show()
